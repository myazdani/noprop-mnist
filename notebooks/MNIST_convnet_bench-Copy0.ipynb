# %%
import cPickle
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score, StratifiedKFold
from sklearn.grid_search import GridSearchCV
from sklearn import linear_model
from scipy import ndimage as ndi
from scipy import *
from scipy import sparse
from scipy import stats
from scipy.ndimage import filters
from sklearn.preprocessing import StandardScaler, Normalizer
from numpy.random import normal
import csv
from sklearn.svm import SVC
from pylab import *
# %matplotlib inline

# %% [markdown]
# # Relevant data setup

# %%
#f = gzip.open('mnist.pkl.gz', 'rb')
f = open('../../data/mnist.pkl', 'rb')
train_set, valid_set, test_set = cPickle.load(f)
f.close()
x = concatenate((train_set[0]*255,valid_set[0]*255,test_set[0][:3000,:]*255))

# %%
num_train = 200

# %%
X_train, y_train = x[:num_train,:], train_set[1][:num_train]
X_test, y_test = x[-3000:,:], test_set[1][:3000]

# %%
scaler = Normalizer().fit(X_train)
X_scaled_train = scaler.transform(X_train)
X_scaled_test = scaler.transform(X_test)

# %% [markdown]
# # Edge detectors:

# %%
img = reshape(X_scaled_train[10,:], (28,28))
imshow(img, cmap = "gray")

# %%
img_dog = ndi.gaussian_filter(img, .09) - ndi.gaussian_filter(img, 2)
imshow(img_dog, cmap = "gray")

# %%
def gauss_deriv(im, sigma):
    imx = zeros(im.shape)
    filters.gaussian_filter(im, (sigma, sigma), (0,1), imx)
    imy = zeros(im.shape)
    filters.gaussian_filter(im, (sigma, sigma), (1,0), imy)
    return sqrt(imx**2 + imy**2)

# %%
imshow(gauss_deriv(img, .5), cmap = "gray")
